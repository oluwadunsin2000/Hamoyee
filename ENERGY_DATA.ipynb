# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import statsmodels.api as sn

# %% [markdown]
# LOADING FILE FROM THIS CSV AND TO VIEW THE SHEETS HEADER

# %%
energy_data = pd.read_csv('C:/Users/HP/Downloads/energy_date.csv')
energy_data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy_data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
df = energy_data.drop(columns=["date","lights"])
x_multi = df.drop(columns=["Appliances"])
y_multi = df["Appliances"]

# %%
x_multi_cons = sn.add_constant(x_multi)
x_multi_cons.head()
# Out:
#    const     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0    1.0  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1    1.0  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2    1.0  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3    1.0  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4    1.0  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
lm_multi = sn.OLS(y_multi, x_multi).fit()
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             Appliances   R-squared (uncentered):                   0.553
# Model:                            OLS   Adj. R-squared (uncentered):              0.552
# Method:                 Least Squares   F-statistic:                              974.0
# Date:                Mon, 03 Aug 2020   Prob (F-statistic):                        0.00
# Time:                        07:54:14   Log-Likelihood:                     -1.1781e+05
# No. Observations:               19735   AIC:                                  2.357e+05
# Df Residuals:                   19710   BIC:                                  2.359e+05
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
lm3 = LinearRegression()
lm3.fit(x_multi, y_multi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm3.intercept_,lm3.coef_)
# Out:
# 35.39450705243921 [ 3.90037951e-01  1.60697476e+01 -2.03066346e+01 -1.44137260e+01
#   2.53748307e+01  5.04884444e+00  2.98096105e+00  1.94908396e+00
#  -2.00418492e-02  2.38143327e-01  7.65953740e+00  3.47287613e-01
#   1.12846672e+00 -1.84188743e+00  1.01512642e+01 -5.90454433e+00
#  -2.20902170e+01 -1.50483862e+00 -1.06403426e+01  1.23219241e-01
#  -9.10467649e-01  2.12894680e+00  1.75814620e-01  5.07626186e+00
#  -2.04810404e-02 -2.04810404e-02]

# %% [markdown]
# NOMILIAZING ENERGY DATA

# %%
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
features_df = normalised_df.drop(columns=["Appliances"])
Appliances_target = normalised_df["Appliances"]

# %% [markdown]
# SPLITING DATASET INTO TRAIN AND TEST

# %%
x_train, x_test, y_train, y_test = train_test_split(features_df,Appliances_target, test_size=0.3, random_state = 42)

# %%
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
predicted_values = linear_model.predict(x_test)
print(linear_model.intercept_,linear_model.coef_)
# Out:
# 0.15290295882253055 [-0.00328105  0.5535466  -0.23617792 -0.45669795  0.29062714  0.09604827
#   0.028981    0.02638578 -0.01565684  0.01600579  0.23642491  0.03804865
#   0.01031878 -0.04461364  0.10199505 -0.15759548 -0.18994077 -0.03980032
#  -0.32185967  0.00683933 -0.07767065  0.02918313  0.01230661  0.11775773
#   0.0007701   0.0007701 ]

# %% [markdown]
# WHAT IS THE MEAN ABSOLUTE ERROR

# %%
mae = mean_absolute_error(y_test, predicted_values)
round(mae,2)
# Out:
# 0.05

# %% [markdown]
# WHAT IS THE RESIDUAL SUM OF SQUARES

# %%
rss = np.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-48ddaf7821e2> in <module>
# ----> 1 rss = np.sum()
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# TypeError: _sum_dispatcher() missing 1 required positional argument: 'a'

# %% [markdown]
# WHAT IS THE ROOTS SQUARED ERROR

# %%
mse = mean_squared_error(y_test,predicted_values)
round(mse,3)
# Out:
# 0.008

# %% [markdown]
# RMSE

# %%
rmse = np.sqrt(mse)
round(rmse,3)
# Out:
# 0.088

# %% [markdown]
# PENALIZATION METHOD

# %%
ridge_reg = Ridge(alpha = 0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
predicted_values = ridge_reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test,predicted_values))
round(rmse,3)
# Out:
# 0.088

# %%
lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
predicted_values = lasso_reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test,predicted_values))
round(rmse,3)
# Out:
# 0.094
